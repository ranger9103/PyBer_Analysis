# %% [markdown]
# %matplotlib inline

# %%
# Import dependencies
import matplotlib.pyplot as plt

# %%
# set the x-axis to a list of strings for each month
x_axis=["Jan","Feb","Mar","April","May","June","July","Aug","Sept","Oct","Nov","Dec"]

# Set the y-axis to a list of floats as the total far in US dollars accumulated for each month
y_axis=[10.2,23.24,39.20,35.42,32.34,27.04,43.82,10.56,11.85,27.90,20.71,20.09]

# %%
# Create the plot
plt.plot(x_axis,y_axis)

# %%
#Create the plot with ax.plt()

fig, ax=plt.subplots()
ax.plot(x_axis,y_axis)

# %%
#creat a plot with ax.plt() - another way to write the line above

fig=plt.figure()
ax=fig.add_subplot()

# %%
#creat plot
fig=plt.figure()
ax=fig.add_subplot()
ax.plot(x_axis,y_axis)

# %%
#create the plot
plt.plot(x_axis,y_axis)
plt.show()

# %%
#create the plot and add a label for the legend
plt.plot(x_axis,y_axis,label='Boston')

#create labels for the x and y ax
plt.xlabel("Date")
plt.ylabel("Fare($)")

# Set the y limit between 0 and 45
plt.ylim(0,45)

# create a title
plt.title("PyBer Fare by Month")

#add the legend
plt.legend()

# %%
# create the plot
plt.plot(x_axis,y_axis,marker="*",color="blue",linewidth=2,label='Boston')

#create labels for x and y 
plt.xlabel("Date")
plt.ylabel("Fare($)")

#set the y limit 0 to 45
plt.ylim(0,45)

#create a title
plt.title("PyBer Fare by Month")

#add grid
plt.grid()

#add legend
plt.legend()

# %%
# create the plot
plt.plot(x_axis,y_axis,marker="D",color="green",linewidth=2,label='Boston')

#create labels for x and y 
plt.xlabel("Date")
plt.ylabel("Fare($)")

#set the y limit 0 to 45
plt.ylim(0,45)

#create a title
plt.title("PyBer Fare by Month")

#add grid
plt.grid()

#add legend
plt.legend()

# %%
# create the plot
plt.bar(x_axis,y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
#create the plot
plt.bar(x_axis,y_axis,color="green",label='Boston')

#create the x and y ax labels
plt.xlabel("Date")
plt.ylabel("Fare($)")

#set the y limit 0 to 45
plt.ylim(0,45)

#create a title
plt.title("PyBer Fare by Month")

#add legend
plt.legend()

# %%
# create horizontal bar chart
plt.barh(x_axis,y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
plt.barh(x_axis,y_axis)
plt.gca().invert_yaxis()

# %%
#create the plot
plt.barh(x_axis,y_axis,color="magenta",label='Boston')

#create the x and y ax labels
plt.xlabel("Date")
plt.ylabel("Fare($)")

#create a title
plt.title("PyBer Fare by Month")

#add legend
plt.legend()

# %%
#create the plot with ax.plt()
fig,ax=plt.subplots()
ax.bar(x_axis,y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
#create the plot with ax.plot()
fig,ax=plt.subplots()
ax.barh(y_axis,x_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
#create the plot
plt.barh(x_axis,y_axis,color="cyan",label='Chicago')
plt.gca().invert_yaxis()

#create the x and y ax labels
plt.xlabel("Date")
plt.ylabel("Fare($)")

#create a title
plt.title("PyBer Fare by Month")

#add legend
plt.legend()

# %%
plt.plot(x_axis,y_axis,'o')

# %%
plt.scatter(x_axis,y_axis)

# %%
plt.scatter(y_axis,x_axis,color="red",label='Chicago')
plt.gca().invert_yaxis()
#create the x and y ax labels
plt.xlabel("Date")
plt.ylabel("Fare($)")

#create a title
plt.title("PyBer Fare by Month")

#add legend
plt.legend()

# %%
#change the size
plt.scatter(x_axis,y_axis,s=y_axis)

# %%
#change the size
plt.scatter(x_axis,y_axis,s=y_axis)
y_axis_larger=[]
for data in y_axis:
    y_axis_larger.append(data*3)
    #change the size
plt.scatter(x_axis,y_axis,s=y_axis)

# %%
#new_list=[expression for item in list if conditional]
plt.scatter(x_axis,y_axis,s=[i*3 for i in y_axis])

# %%
#object oriented chart
fig, ax=plt.subplots()
ax.scatter(x_axis,y_axis)

# %%
#object oriented bubble chart
fig,ax=plt.subplots()
#5 times size, color sky blue
ax.scatter(y_axis,x_axis,s=[i*5 for i in y_axis],color="skyblue", label='Boston', linewidth=2.0, edgecolor='black', alpha=0.8)

plt.gca().invert_yaxis()

#create the x and y ax labels
plt.xlabel("Date")
plt.ylabel("Fare($)")

#create a title
plt.title("PyBer Fare by Month")


#set the y limit 0 to 45
plt.xlim(0,45)

#add legend
plt.legend()

# %%
#create pie chart
plt.pie(y_axis,labels=x_axis)
plt.show()

# %%
explode_values=(0,0,0,0,0,0,0.2,0,0,0,0,0)
plt.pie(y_axis,explode=explode_values, labels=x_axis, autopct='%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x29ac8f34d48>,
#   <matplotlib.patches.Wedge at 0x29ac8f56a48>,
#   <matplotlib.patches.Wedge at 0x29ac8f5da88>,
#   <matplotlib.patches.Wedge at 0x29ac8f62b08>,
#   <matplotlib.patches.Wedge at 0x29ac8f69b88>,
#   <matplotlib.patches.Wedge at 0x29ac8f70c88>,
#   <matplotlib.patches.Wedge at 0x29ac8f77cc8>,
#   <matplotlib.patches.Wedge at 0x29ac8f7dd08>,
#   <matplotlib.patches.Wedge at 0x29ac8f69b48>,
#   <matplotlib.patches.Wedge at 0x29ac8f70c48>,
#   <matplotlib.patches.Wedge at 0x29ac8f22dc8>,
#   <matplotlib.patches.Wedge at 0x29ac8f98c88>],
#  [Text(1.0938286683729845, 0.11635653933227785, 'Jan'),
#   Text(0.988852078978306, 0.4818418473942279, 'Feb'),
#   Text(0.49683694789234356, 0.9814036107580922, 'Mar'),
#   Text(-0.3320614549143908, 1.048682597433627, 'April'),
#   Text(-0.9319109555047855, 0.5844159229608292, 'May'),
#   Text(-1.0982239962319433, -0.06248243033317857, 'June'),
#   Text(-0.9121681158454136, -0.9262555416487549, 'July'),
#   Text(-0.23224532853912386, -1.0752032865331813, 'Aug'),
#   Text(0.022113482644236203, -1.0997777020313437, 'Sept'),
#   Text(0.4616581091335332, -0.9984346700066313, 'Oct'),
#   Text(0.887115861036946, -0.6504040660210221, 'Nov'),
#   Text(1.0761236913984105, -0.22794253839741907, 'Dec')],
#  [Text(0.5966338191125369, 0.06346720327215155, '3.4%'),
#   Text(0.539373861260894, 0.262822825851397, '7.7%'),
#   Text(0.2710019715776419, 0.5353110604135047, '13.0%'),
#   Text(-0.18112442995330405, 0.572008689509251, '11.7%'),
#   Text(-0.5083150666389739, 0.3187723216149977, '10.7%'),
#   Text(-0.599031270671969, -0.03408132563627921, '8.9%'),
#   Text(-0.5613342251356391, -0.5700034102453876, '14.5%'),
#   Text(-0.12667927011224936, -0.5864745199271898, '3.5%'),
#   Text(0.012061899624128838, -0.5998787465625511, '3.9%'),
#   Text(0.2518135140728363, -0.5446007290945261, '9.2%'),
#   Text(0.483881378747425, -0.35476585419328477, '6.8%'),
#   Text(0.5869765589445874, -0.12433229367131948, '6.6%')])

# %%
#assign 12 colors, one for each month
colors=["slateblue","magenta","lightblue","green","yellowgreen","greenyellow","yellow","orange","gold","indianred","tomato","mistyrose"]
explode_values=(0,0,0,0,0,0,0.2,0,0,0,0,0)
plt.subplots(figsize=(8,8))
plt.pie(y_axis,
       explode=explode_values,
       labels=x_axis,
       autopct='%.1f%%',
       colors=colors,
       shadow=True)

plt.show()

# %%
# same but object oriented - adding %, figure size 8x8, explode two highest percentage months, add shadow,
#start with january on top, reverse month order, new colors
fig,ax=plt.subplots()
explode_values=(0,0,0.2,0,0,0,0.2,0,0,0,0,0)
ax.pie(y_axis,labels=x_axis,shadow=True, explode=explode_values, autopct='%1.1f%%',startangle=263)
plt.gca().invert_yaxis()
#ax.pie(colors("slateblue","magenta","lightblue","green","yellowgreen","greenyellow","yellow","orange","gold","indianred","tomato","mistyrose")
#fig=plt.figure(figsize=(8,8))

# **** can't get the color to work or size *****
plt.show()
